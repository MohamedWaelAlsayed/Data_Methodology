# %%
import pandas as pd

# %%
original_data=pd.read_csv('hotel_bookings.csv')

# %%
original_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data=original_data.copy()

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data['arrival_date']=data['arrival_date_year'].astype('str')+data['arrival_date_month']+data['arrival_date_day_of_month'].astype('str')

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data['arrival_date']=pd.to_datetime(data['arrival_date'],format='%Y%B%d')

# %%
data.drop('arrival_date_year',axis=1)
# Out:
#                hotel  is_canceled  lead_time arrival_date_month  \
# 0       Resort Hotel            0        342               July
# 1       Resort Hotel            0        737               July
# 2       Resort Hotel            0          7               July
# 3       Resort Hotel            0         13               July
# 4       Resort Hotel            0         14               July
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23             August
# 119386    City Hotel            0        102             August
# 119387    City Hotel            0         34             August
# 119388    City Hotel            0        109             August
# 119389    City Hotel            0        205             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# 1                             27                          1
# ...

# %%
data.drop('arrival_date_month',axis=1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# 1                             27                          1
# ...

# %%
data.drop('arrival_date_day_of_month',axis=1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  stays_in_weekend_nights  \
# 0                    July                        27                        0
# ...

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data=data.drop('arrival_date_year',axis=1)

# %%
data=data.drop('arrival_date_month',axis=1)
data=data.drop('arrival_date_day_of_month',axis=1)

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data['children'].isnull().sum()
# Out:
# 4

# %%
data.isnull().sum(axis=0)
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_week_number               0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# ...

# %%
data['children'].isnull().sum()
# Out:
# 4

# %%
data['children'].loc[data['children'].isnull()]=0
# Out:
# C:\Users\engmo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data['children']=data['children'].astype(int)

# %%
data['children'].isnull().sum()
# Out:
# 0

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   children                        119390 non-null  int32
#  8   babies                          119390 non-null  int64
#  9   meal                            119390 non-null  object
#  10  country                         118902 non-null  object
#  11  market_segment                  119390 non-null  object
# ...

# %%
data['agent'].loc[data['agent'].isnull()]=0
# Out:
# C:\Users\engmo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data['company'].loc[data['company'].isnull()]=0

# %%
data.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_week_number            0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            0
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# days_in_waiting_list                0
# customer_type                       0
# adr                                 0
# ...

# %%
data['agent or company']=data['agent']+data['company']

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   children                        119390 non-null  int32
#  8   babies                          119390 non-null  int64
#  9   meal                            119390 non-null  object
#  10  country                         118902 non-null  object
#  11  market_segment                  119390 non-null  object
# ...

# %%
data=data.drop('agent',axis=1)

# %%
data=data.drop('company',axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   children                        119390 non-null  int32
#  8   babies                          119390 non-null  int64
#  9   meal                            119390 non-null  object
#  10  country                         118902 non-null  object
#  11  market_segment                  119390 non-null  object
# ...

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data['agent or company']=data['agent or company'].replace(0,'no ID')

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data['non_adults']=data['children']+data['babies']

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
data=data.drop('children',axis=1)
data=data.drop('babies',axis=1)

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# ...

# %%
data['country'].loc[data['country'].isnull()]='_'
# Out:
# C:\Users\engmo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_week_number          0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# arrival_date                      0
# ...

# %%
data['reservation_status_date']=pd.to_datetime(data['reservation_status_date'])

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   meal                            119390 non-null  object
#  8   country                         119390 non-null  object
#  9   market_segment                  119390 non-null  object
#  10  distribution_channel            119390 non-null  object
#  11  is_repeated_guest               119390 non-null  int64
# ...

# %%
 pd.set_option('display.max_columns', None)

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0       Resort Hotel            0        342                        27
# 1       Resort Hotel            0        737                        27
# 2       Resort Hotel            0          7                        27
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   meal                            119390 non-null  object
#  8   country                         119390 non-null  object
#  9   market_segment                  119390 non-null  object
#  10  distribution_channel            119390 non-null  object
#  11  is_repeated_guest               119390 non-null  int64
# ...

# %%
data['reserved_room_type']=data['reserved_room_type'].astype('category')
data['assigned_room_type']=data['assigned_room_type'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   meal                            119390 non-null  object
#  8   country                         119390 non-null  object
#  9   market_segment                  119390 non-null  object
#  10  distribution_channel            119390 non-null  object
#  11  is_repeated_guest               119390 non-null  int64
# ...

# %%
#removing all no Id values
data = data[data['agent or company']!='no ID']
#changing the type of column agent or copany
data['agent or company'] = data['agent or company'].astype(int)
# Out:
# <ipython-input-118-a6401339daaf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['agent or company'] = data['agent or company'].astype(int)

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# 5       Resort Hotel            0         14                        27
# 7       Resort Hotel            0          9                        27
# 8       Resort Hotel            1         85                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# ...

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109630 entries, 3 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           109630 non-null  object
#  1   is_canceled                     109630 non-null  int64
#  2   lead_time                       109630 non-null  int64
#  3   arrival_date_week_number        109630 non-null  int64
#  4   stays_in_weekend_nights         109630 non-null  int64
#  5   stays_in_week_nights            109630 non-null  int64
#  6   adults                          109630 non-null  int64
#  7   meal                            109630 non-null  object
#  8   country                         109630 non-null  object
#  9   market_segment                  109630 non-null  object
#  10  distribution_channel            109630 non-null  object
#  11  is_repeated_guest               109630 non-null  int64
# ...

# %%
data=data.rename(columns={'agent or company' : 'agent_or_company' })

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# 5       Resort Hotel            0         14                        27
# 7       Resort Hotel            0          9                        27
# 8       Resort Hotel            1         85                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# ...

# %%
data.min()
# Out:
# hotel                                      City Hotel
# is_canceled                                         0
# lead_time                                           0
# arrival_date_week_number                            1
# stays_in_weekend_nights                             0
# stays_in_week_nights                                0
# adults                                              0
# meal                                               BB
# country                                           ABW
# market_segment                               Aviation
# distribution_channel                        Corporate
# is_repeated_guest                                   0
# previous_cancellations                              0
# previous_bookings_not_canceled                      0
# booking_changes                                     0
# deposit_type                               No Deposit
# days_in_waiting_list                                0
# ...

# %%
#removing data that is less than 40
data = data[data.adr>40]
data[data.adr<40]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_week_number, stays_in_weekend_nights, stays_in_week_nights, adults, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, arrival_date, agent_or_company, non_adults]
# Index: []

# %%
data.loc[data['adr'] == -6.38, 'adr'] = data.mode()['adr']
data.loc[data['adr'] == 50000, 'adr'] = data.mode()['adr']
# Out:
# C:\Users\engmo\anaconda3\lib\site-packages\pandas\core\indexing.py:1760: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)
# C:\Users\engmo\anaconda3\lib\site-packages\pandas\core\indexing.py:1760: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)
# Empty DataFrame
# ...

# %%
#Assess
data[data.adr==5000]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_week_number, stays_in_weekend_nights, stays_in_week_nights, adults, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, arrival_date, agent_or_company, non_adults, adr]
# Index: []

# %%
#Assess
data[data.adr==-6.38]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_week_number, stays_in_weekend_nights, stays_in_week_nights, adults, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, arrival_date, agent_or_company, non_adults, adr]
# Index: []

# %%
data.min()
# Out:
# hotel                                      City Hotel
# is_canceled                                         0
# lead_time                                           0
# arrival_date_week_number                            1
# stays_in_weekend_nights                             0
# stays_in_week_nights                                0
# adults                                              0
# meal                                               BB
# country                                           ABW
# market_segment                               Aviation
# distribution_channel                        Corporate
# is_repeated_guest                                   0
# previous_cancellations                              0
# previous_bookings_not_canceled                      0
# booking_changes                                     0
# deposit_type                               No Deposit
# days_in_waiting_list                                0
# ...

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# 5       Resort Hotel            0         14                        27
# 7       Resort Hotel            0          9                        27
# 8       Resort Hotel            1         85                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# ...

# %%
 data['hotel']=data['hotel'].astype('category')
 data['meal']=data['meal'].astype('category')
 data['country']=data['country'].astype('category')
# Out:
# <ipython-input-128-6ea449527966>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['hotel']=data['hotel'].astype('category')
# <ipython-input-128-6ea449527966>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['meal']=data['meal'].astype('category')
# <ipython-input-128-6ea449527966>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#changing column place
data['adr2']=data['adr']
data=data.drop('adr',axis=1)
data=data.rename(columns={'adr2' : 'adr' })
# Out:
# <ipython-input-129-25708fe2e063>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['adr2']=data['adr']

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 3       Resort Hotel            0         13                        27
# 4       Resort Hotel            0         14                        27
# 5       Resort Hotel            0         14                        27
# 7       Resort Hotel            0          9                        27
# 8       Resort Hotel            1         85                        27
# ...              ...          ...        ...                       ...
# 119385    City Hotel            0         23                        35
# 119386    City Hotel            0        102                        35
# 119387    City Hotel            0         34                        35
# 119388    City Hotel            0        109                        35
# 119389    City Hotel            0        205                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103988 entries, 3 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           103988 non-null  category
#  1   is_canceled                     103988 non-null  int64
#  2   lead_time                       103988 non-null  int64
#  3   arrival_date_week_number        103988 non-null  int64
#  4   stays_in_weekend_nights         103988 non-null  int64
#  5   stays_in_week_nights            103988 non-null  int64
#  6   adults                          103988 non-null  int64
#  7   meal                            103988 non-null  category
#  8   country                         103988 non-null  category
#  9   market_segment                  103988 non-null  object
#  10  distribution_channel            103988 non-null  object
#  11  is_repeated_guest               103988 non-null  int64
# ...

# %%
data.to_csv('DS project.csv',index=False)
